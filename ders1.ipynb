# %%
import time
millis1=int(round(time.time()))
print(millis1)
time.sleep(5)
millis2=int(round(time.time()))
print(millis2)
print(millis2-millis1)
# Out:
# 1519386136
# 1519386141
# 5

# %%
def fibo_rec(n):
    if(n<2):
        return n
    else:
        return fibo_rec(n-1)+fibo_rec(n-2)

# %%
fibo_rec(0),fibo_rec(1),fibo_rec(2),fibo_rec(3),fibo_rec(4),fibo_rec(5)
# Out:
# (0, 1, 1, 2, 3, 5)

# %%
def fibo_loop(n):
    if(n<2):
        return n
    else:
        a=0
        b=1
    while(n>0):
        c=a+b
        a=b
        b=c
        n=n-1
    return c

def fibo_rec(n):
    if(n<2):
        return n
    else:
        return fibo_rec(n-1)+fibo_rec(n-2)

fibo_loop(0),fibo_loop(1), fibo_loop(2), fibo_loop(3),fibo_loop(4), fibo_loop(5)
# Out:
# (0, 1, 2, 3, 5, 8)

# %%
n=40
time1=int(round(time.time()))
fibo_rec(n)
time2=int(round(time.time()))
print(n," için geçen süre : ",time2-time1,"saniye")
# Out:
# 40  için geçen süre :  133 saniye

# %%
for n in range(40):
    time1=int(round(time.time()))
    fibo_rec(n)
    time2=int(round(time.time()))
    print("recursive ve np olan :",n," için geçen süre : ",time2-time1,"saniye")
    time3=int(round(time.time()))
    fibo_loop(n)
    time4=int(round(time.time()))
    print("-----------------------------------------------------------")
    print("loop p(linear) olan : ",n," için geçen süre : ",time4-time3,"saniye")
# Out:
# recursive ve np olan : 0  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  0  için geçen süre :  0 saniye
# recursive ve np olan : 1  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  1  için geçen süre :  0 saniye
# recursive ve np olan : 2  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  2  için geçen süre :  0 saniye
# recursive ve np olan : 3  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  3  için geçen süre :  0 saniye
# recursive ve np olan : 4  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  4  için geçen süre :  0 saniye
# recursive ve np olan : 5  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  5  için geçen süre :  0 saniye
# recursive ve np olan : 6  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  6  için geçen süre :  0 saniye
# recursive ve np olan : 7  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  7  için geçen süre :  0 saniye
# recursive ve np olan : 8  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  8  için geçen süre :  0 saniye
# recursive ve np olan : 9  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  9  için geçen süre :  0 saniye
# recursive ve np olan : 10  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  10  için geçen süre :  0 saniye
# recursive ve np olan : 11  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  11  için geçen süre :  0 saniye
# recursive ve np olan : 12  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  12  için geçen süre :  0 saniye
# recursive ve np olan : 13  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  13  için geçen süre :  0 saniye
# recursive ve np olan : 14  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  14  için geçen süre :  0 saniye
# recursive ve np olan : 15  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  15  için geçen süre :  0 saniye
# recursive ve np olan : 16  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  16  için geçen süre :  0 saniye
# recursive ve np olan : 17  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  17  için geçen süre :  0 saniye
# recursive ve np olan : 18  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  18  için geçen süre :  0 saniye
# recursive ve np olan : 19  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  19  için geçen süre :  0 saniye
# recursive ve np olan : 20  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  20  için geçen süre :  0 saniye
# recursive ve np olan : 21  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  21  için geçen süre :  0 saniye
# recursive ve np olan : 22  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  22  için geçen süre :  0 saniye
# recursive ve np olan : 23  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  23  için geçen süre :  0 saniye
# recursive ve np olan : 24  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  24  için geçen süre :  0 saniye
# recursive ve np olan : 25  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  25  için geçen süre :  0 saniye
# recursive ve np olan : 26  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  26  için geçen süre :  0 saniye
# recursive ve np olan : 27  için geçen süre :  1 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  27  için geçen süre :  0 saniye
# recursive ve np olan : 28  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  28  için geçen süre :  0 saniye
# recursive ve np olan : 29  için geçen süre :  1 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  29  için geçen süre :  0 saniye
# recursive ve np olan : 30  için geçen süre :  1 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  30  için geçen süre :  0 saniye
# recursive ve np olan : 31  için geçen süre :  2 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  31  için geçen süre :  0 saniye
# recursive ve np olan : 32  için geçen süre :  3 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  32  için geçen süre :  0 saniye
# recursive ve np olan : 33  için geçen süre :  4 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  33  için geçen süre :  0 saniye
# recursive ve np olan : 34  için geçen süre :  8 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  34  için geçen süre :  0 saniye
# recursive ve np olan : 35  için geçen süre :  12 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  35  için geçen süre :  0 saniye

# %%
import matplotlib.pyplot as plt
for n in range(40):
    time1=int(round(time.time()))
    fibo_rec(n)
    time2=int(round(time.time()))
    print("recursive ve np olan :",n," için geçen süre : ",time2-time1,"saniye")
    time3=int(round(time.time()))
    fibo_loop(n)
    time4=int(round(time.time()))
    print("-----------------------------------------------------------")
    print("loop p(linear) olan : ",n," için geçen süre : ",time4-time3,"saniye")
    plt.plot([n,time2-time1])
    plt.plot([n,time4-time3])
    plt.xlabel("Orange : np values\n Blue : loop values")
    plt.show()
# Out:
# recursive ve np olan : 0  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  0  için geçen süre :  0 saniye
# recursive ve np olan : 1  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  1  için geçen süre :  0 saniye
# recursive ve np olan : 2  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  2  için geçen süre :  0 saniye
# recursive ve np olan : 3  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  3  için geçen süre :  0 saniye
# recursive ve np olan : 4  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  4  için geçen süre :  0 saniye
# recursive ve np olan : 5  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  5  için geçen süre :  0 saniye
# recursive ve np olan : 6  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  6  için geçen süre :  0 saniye
# recursive ve np olan : 7  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  7  için geçen süre :  0 saniye
# recursive ve np olan : 8  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  8  için geçen süre :  0 saniye
# recursive ve np olan : 9  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  9  için geçen süre :  0 saniye
# recursive ve np olan : 10  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  10  için geçen süre :  0 saniye
# recursive ve np olan : 11  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  11  için geçen süre :  0 saniye
# recursive ve np olan : 12  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  12  için geçen süre :  0 saniye
# recursive ve np olan : 13  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  13  için geçen süre :  0 saniye
# recursive ve np olan : 14  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  14  için geçen süre :  0 saniye
# recursive ve np olan : 15  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  15  için geçen süre :  0 saniye
# recursive ve np olan : 16  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  16  için geçen süre :  0 saniye
# recursive ve np olan : 17  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  17  için geçen süre :  0 saniye
# recursive ve np olan : 18  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  18  için geçen süre :  0 saniye
# recursive ve np olan : 19  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  19  için geçen süre :  0 saniye
# recursive ve np olan : 20  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  20  için geçen süre :  0 saniye
# recursive ve np olan : 21  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  21  için geçen süre :  0 saniye
# recursive ve np olan : 22  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  22  için geçen süre :  0 saniye
# recursive ve np olan : 23  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  23  için geçen süre :  0 saniye
# recursive ve np olan : 24  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  24  için geçen süre :  0 saniye
# recursive ve np olan : 25  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  25  için geçen süre :  0 saniye
# recursive ve np olan : 26  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  26  için geçen süre :  0 saniye
# recursive ve np olan : 27  için geçen süre :  0 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  27  için geçen süre :  0 saniye
# recursive ve np olan : 28  için geçen süre :  1 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  28  için geçen süre :  0 saniye
# recursive ve np olan : 29  için geçen süre :  1 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  29  için geçen süre :  0 saniye
# recursive ve np olan : 30  için geçen süre :  1 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  30  için geçen süre :  0 saniye
# recursive ve np olan : 31  için geçen süre :  2 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  31  için geçen süre :  0 saniye
# recursive ve np olan : 32  için geçen süre :  3 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  32  için geçen süre :  0 saniye
# recursive ve np olan : 33  için geçen süre :  4 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  33  için geçen süre :  0 saniye
# recursive ve np olan : 34  için geçen süre :  7 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  34  için geçen süre :  0 saniye
# recursive ve np olan : 35  için geçen süre :  11 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  35  için geçen süre :  0 saniye
# recursive ve np olan : 36  için geçen süre :  20 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  36  için geçen süre :  0 saniye
# recursive ve np olan : 37  için geçen süre :  31 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  37  için geçen süre :  0 saniye
# recursive ve np olan : 38  için geçen süre :  51 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  38  için geçen süre :  0 saniye
# recursive ve np olan : 39  için geçen süre :  86 saniye
# -----------------------------------------------------------
# loop p(linear) olan :  39  için geçen süre :  0 saniye
